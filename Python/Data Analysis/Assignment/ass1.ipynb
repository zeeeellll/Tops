# %% [markdown]
# **Importance of Data Cleaning in Data Science**
#
# Data has become one of the most valuable assets in the digital age, often referred to as the “new oil.” However, raw data is rarely perfect. It often contains errors, inconsistencies, and missing values that can mislead analysis and lead to incorrect conclusions. This is where **data cleaning**, also known as data cleansing or data scrubbing, becomes an essential step in the **data science** workflow.
#
# ### What is Data Cleaning?
#
# Data cleaning is the process of identifying and correcting (or removing) inaccurate records from a dataset. It includes handling missing values, removing duplicate records, correcting inconsistent formatting, and eliminating outliers or irrelevant data. This process ensures that the data is accurate, complete, and reliable for analysis and modeling.
#
# ### Why is Data Cleaning Important?
#
# 1. **Improves Data Quality**
#
#    The main goal of data cleaning is to improve data quality. High-quality data is accurate, consistent, and up-to-date. Clean data ensures that the results of data analysis and machine learning models are trustworthy and actionable.
#
# 2. **Enhances Decision-Making**
#
#    Organizations rely on data to make informed decisions. If the underlying data is flawed, the decisions based on it can be disastrous. Clean data helps in making precise predictions, identifying trends, and supporting strategic decisions.
#
# 3. **Increases Model Accuracy**
#
#    In machine learning, the performance of a model heavily depends on the quality of input data. Dirty data can reduce the accuracy of predictions. By cleaning the data, we can ensure that the model learns the right patterns, leading to better outcomes.
#
# 4. **Saves Time and Resources**
#
#    Although data cleaning can be time-consuming, it saves time in the long run. Working with clean data reduces the chances of errors in analysis and prevents the need to repeat processes. It also helps avoid costly mistakes caused by poor-quality data.
#
# 5. **Ensures Compliance and Standardization**
#
#    Many industries are governed by regulations that require data to be maintained accurately. Data cleaning helps in maintaining compliance by ensuring that data is recorded and stored correctly. It also helps standardize data from multiple sources, making integration and comparison easier.
#
# 6. **Facilitates Effective Data Visualization**
#
#    Dirty data can distort visualizations and graphs, making them misleading. Clean data supports the creation of clear, meaningful, and accurate visualizations that help stakeholders understand key insights at a glance.
#
# ### Challenges in Data Cleaning
#
# Data cleaning can be a complex and tedious task, especially when dealing with large datasets. Some of the common challenges include:
# - Identifying hidden inconsistencies
# - Dealing with unstructured or semi-structured data
# - Handling different formats and units
# - Balancing between removing errors and losing valuable data
#
# Despite these challenges, modern tools and libraries like **Pandas**, **NumPy**, and **OpenRefine** have made data cleaning more efficient and manageable.
#
# ### Conclusion
#
# Data cleaning is a crucial step in the data science process. Without clean data, even the most sophisticated algorithms and analyses can produce flawed results. By investing time and effort into cleaning data, data scientists can ensure better accuracy, reliability, and trust in their findings. As the saying goes in the world of data science: *“Garbage in, garbage out.”* Clean data is the foundation upon which valuable insights are built.

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate as tb

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #### First we split the data into numerical format and Categotical or discrit formation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
num_cols = df.select_dtypes(include = ['float64','int64'])
cat_cols = df.select_dtypes(include = ['object'])

# %%
print(num_cols.info())
print()
print(cat_cols.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              11914 non-null  int64
#  1   Engine HP         11845 non-null  float64
#  2   Engine Cylinders  11884 non-null  float64
#  3   Number of Doors   11908 non-null  float64
#  4   highway MPG       11914 non-null  int64
#  5   city mpg          11914 non-null  int64
#  6   Popularity        11914 non-null  int64
#  7   MSRP              11914 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 744.8 KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
# ...

# %%
num_cols
# Out:
#        Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# 0      2011      335.0               6.0              2.0           26
# 1      2011      300.0               6.0              2.0           28
# 2      2011      300.0               6.0              2.0           28
# 3      2011      230.0               6.0              2.0           28
# 4      2011      230.0               6.0              2.0           28
# ...     ...        ...               ...              ...          ...
# 11909  2012      300.0               6.0              4.0           23
# 11910  2012      300.0               6.0              4.0           23
# 11911  2012      300.0               6.0              4.0           23
# 11912  2013      300.0               6.0              4.0           23
# 11913  2006      221.0               6.0              4.0           26
#
#        city mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# ...

# %% [markdown]
# ### Now here i handle numerica null values and fill in meaning full ways

# %%
num_cols.isna().sum()
# Out:
# Year                 0
# Engine HP           69
# Engine Cylinders    30
# Number of Doors      6
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ### Here i fill values of Engine_HP by mean() and another two by mode()

# %%
num_cols['Engine HP'].fillna(df['Engine HP'].mean(),inplace=True)
num_cols['Number of Doors'].fillna(df['Number of Doors'].mode()[0],inplace=True)
num_cols['Engine Cylinders'].fillna(df['Engine Cylinders'].mode()[0],inplace=True)
# Out:
# C:\Users\MAHADEV\AppData\Local\Temp\ipykernel_1716\1348102828.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   num_cols['Engine HP'].fillna(df['Engine HP'].mean(),inplace=True)
# C:\Users\MAHADEV\AppData\Local\Temp\ipykernel_1716\1348102828.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### Handle of Categorical data's null values

# %%
cat_cols
# Out:
#           Make       Model                Engine Fuel Type Transmission Type  \
# 0          BMW  1 Series M     premium unleaded (required)            MANUAL
# 1          BMW    1 Series     premium unleaded (required)            MANUAL
# 2          BMW    1 Series     premium unleaded (required)            MANUAL
# 3          BMW    1 Series     premium unleaded (required)            MANUAL
# 4          BMW    1 Series     premium unleaded (required)            MANUAL
# ...        ...         ...                             ...               ...
# 11909    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11910    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11911    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11912    Acura         ZDX  premium unleaded (recommended)         AUTOMATIC
# 11913  Lincoln      Zephyr                regular unleaded         AUTOMATIC
#
# ...

# %% [markdown]
# ### Here i fill the null values of Mode function

# %%
cat_cols['Engine Fuel Type'].fillna(cat_cols['Engine Fuel Type'].mode()[0],inplace=True)
cat_cols['Market Category'].fillna(cat_cols['Market Category'].mode()[0],inplace=True)
# Out:
# C:\Users\MAHADEV\AppData\Local\Temp\ipykernel_1716\2878194976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cat_cols['Engine Fuel Type'].fillna(cat_cols['Engine Fuel Type'].mode()[0],inplace=True)
# C:\Users\MAHADEV\AppData\Local\Temp\ipykernel_1716\2878194976.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### Now we don't have any kind of null values

# %%
print(cat_cols.isna().sum())
print()
print(num_cols.isna().sum())
# Out:
# Make                 0
# Model                0
# Engine Fuel Type     0
# Transmission Type    0
# Driven_Wheels        0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# dtype: int64
#
# Year                0
# Engine HP           0
# Engine Cylinders    0
# Number of Doors     0
# highway MPG         0
# city mpg            0
# Popularity          0
# MSRP                0
# dtype: int64

# %% [markdown]
# ### Now we understand the overall aspects by using visualization techniques

# %% [markdown]
# #### Firstly Apply in numerical data

# %%
num_cols
# Out:
#        Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# 0      2011      335.0               6.0              2.0           26
# 1      2011      300.0               6.0              2.0           28
# 2      2011      300.0               6.0              2.0           28
# 3      2011      230.0               6.0              2.0           28
# 4      2011      230.0               6.0              2.0           28
# ...     ...        ...               ...              ...          ...
# 11909  2012      300.0               6.0              4.0           23
# 11910  2012      300.0               6.0              4.0           23
# 11911  2012      300.0               6.0              4.0           23
# 11912  2013      300.0               6.0              4.0           23
# 11913  2006      221.0               6.0              4.0           26
#
#        city mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# ...

# %% [markdown]
# ##### First check outliers of numerical data by using boxplot

# %%
sns.boxenplot(num_cols['Engine HP'])

second_max = num_cols['Engine HP'].unique()
second_max.sort()

print("Engine HP outliers is : ",num_cols['Engine HP'].max()," and :",second_max[-2])
# Out:
# Engine HP outliers is :  1001.0  and : 750.0

# %% [markdown]
# ##### Here i create scatter plot for knowing which year gap have how many engine_hp

# %%
sns.set_palette("muted") 
sns.scatterplot(x = num_cols['Year'],y = num_cols['Engine HP'])
# Out:
# <Axes: xlabel='Year', ylabel='Engine HP'>

# %% [markdown]
# ##### Here we check popularity by year using line plot

# %%
sns.set_palette('Set1')
sns.lineplot(x = num_cols['Year'],y = num_cols['Popularity'],ci=None,marker='o')
# Out:
# C:\Users\MAHADEV\AppData\Local\Temp\ipykernel_1716\1671250165.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = num_cols['Year'],y = num_cols['Popularity'],ci=None,marker='o')
# <Axes: xlabel='Year', ylabel='Popularity'>

# %% [markdown]
# #### Now, we move on categorical scenario

# %%
cat_cols
# Out:
#           Make       Model                Engine Fuel Type Transmission Type  \
# 0          BMW  1 Series M     premium unleaded (required)            MANUAL
# 1          BMW    1 Series     premium unleaded (required)            MANUAL
# 2          BMW    1 Series     premium unleaded (required)            MANUAL
# 3          BMW    1 Series     premium unleaded (required)            MANUAL
# 4          BMW    1 Series     premium unleaded (required)            MANUAL
# ...        ...         ...                             ...               ...
# 11909    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11910    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11911    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11912    Acura         ZDX  premium unleaded (recommended)         AUTOMATIC
# 11913  Lincoln      Zephyr                regular unleaded         AUTOMATIC
#
# ...

# %% [markdown]
# #### Here i create countplot to know which brand contain more count

# %%
plt.figure(figsize=(10,12))
sns.set_palette('dark')
sns.countplot(cat_cols['Make'])
plt.title('Count plot of Make')
# Out:
# Text(0.5, 1.0, 'Count plot of Make')

# %% [markdown]
# #### Here i check Unique value count and Top 10 Market Categories on Market Category

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y=cat_cols['Market Category'], order=cat_cols['Market Category'].value_counts().index[:10], color='teal')
plt.title('Top 10 Market Categories')
plt.xlabel('Count')
plt.ylabel('Market Category')
plt.show()

# %% [markdown]
# ##### Countplot based on Vehicle Style

# %%
sns.countplot(y = cat_cols['Vehicle Style'],order= cat_cols['Vehicle Style'].value_counts().index[:10])
# Out:
# <Axes: xlabel='count', ylabel='Vehicle Style'>

# %% [markdown]
# #### Now, we visualize combining both Categorical value and Numerical values also

# %% [markdown]
# #####  Here i create line plot to understand which year has which type of Vehicle Size according Driven wheels

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x=cat_cols['Vehicle Size'], y=num_cols['Year'], hue=cat_cols['Driven_Wheels'],data=df,ci=None,palette='rocket',marker='o')
# Out:
# C:\Users\MAHADEV\AppData\Local\Temp\ipykernel_1716\2013771950.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=cat_cols['Vehicle Size'], y=num_cols['Year'], hue=cat_cols['Driven_Wheels'],data=df,ci=None,palette='rocket',marker='o')
# <Axes: xlabel='Vehicle Size', ylabel='Year'>

# %%
top_10_make = cat_cols['Make'].value_counts().index[:10]
year = num_cols['Year'].value_counts().index[:10]

# %%
sns.lineplot(x = year,y = top_10_make,marker='o')
plt.grid(alpha = .3)

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=cat_cols['Vehicle Size'], y=num_cols['Number of Doors'],hue=num_cols['Year'])
# Out:
# <Axes: xlabel='Vehicle Size', ylabel='Number of Doors'>
