# %%
class computer:
    def spe(self):
        print("Ryzen 7")

obj = computer()
obj.spe()
# Out:
# Ryzen 7

# %%
class books:

    def __init__(self):
        #self.b_name = b_name
        #self.page = page
        pass

    def Rhonda(self,b_name,page):
        self.b_name = b_name
        self.page = page
        print("By Rhonda Byrne",self.b_name,self.page)

obj = books()
obj2 = books()
obj.Rhonda("The Secret",216)
obj2.Rhonda("The magic",272)
# Out:
# By Rhonda Byrne The Secret 216
# By Rhonda Byrne The magic 272

# %%
a = input("Enter something : ").strip().capitalize()
a
# Out:
# 'Rm'

# %%
d = {'a' : 10,
     'b' : 20
     }

d
# Out:
# {'a': 10, 'b': 20}

# %%
d['c'] = 10
d
d['c'] += 5
d
# Out:
# {'a': 10, 'b': 20, 'c': 15}

# %%
def add_fruit():

    fruit =  input("Enter name : ").capitalize().strip()
    if not fruit:
        print("Enter valid fruit name !")
        return
    try:
        q = int(input("Enter quatity : "))
        if q <= 0 :
          print("Enter valid quatity greater than 0")
        
        if fruit in d :
            d[fruit] += q
        else :
            d[fruit] = q
    except:
        print("Fill up valid details !")

# %%
add_fruit()
# Out:
# Enter valid fruit name !

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 15, 'Apple': 5}

# %%
if not d.items():
    print("Dictinory is empty !")
else:
    print(d)
# Out:
# {'a': 10, 'b': 20, 'c': 15, 'Apple': 5}

# %%
def view_stock():
    if not d.items():
        print("Fruit set is empty")
    else:
        for fruits,q in d.items():
                print(f"{fruits} and quatity is {q}")

# %%
view_stock()
# Out:
# a and quatity is 10
# b and quatity is 20
# c and quatity is 15
# Apple and quatity is 5

# %%
def update_stock():
    if not d.items():
        print("Fruit set is empty")
    return

try:
    update_fruit = input("Enter your update data : ")
    if update_fruit in d:
        qu = input("Enter quatity to update : ")
        d[update_fruit] = qu
    else:
       print("fruit is not available in data !")
except:
    print("something is wrong")

# %%
update_stock()
d
# Out:
# {'a': '7', 'b': 20, 'c': 15, 'Apple': 5}

# %%
class manager():

    def add_fruit():

        fruit =  input("Enter name : ").capitalize().strip()
        if not fruit:
             print("Enter valid fruit name !")
             return
        try:
            q = int(input("Enter quatity : "))
            if q <= 0 :
                print("Enter valid quatity greater than 0")
        
            if fruit in d :
                d[fruit] += q
            else :
                d[fruit] = q
        except:
             print("Fill up valid details !")


    def view_stock():
        if not d.items():
            print("Fruit set is empty")
        else:
            for fruits,q in d.items():
                print(f"{fruits} and quatity is {q}")

    def update_stock():
        if not d.items():
            print("Fruit set is empty")
        return
    try:
            update_fruit = input("Enter your update data : ")
            if update_fruit in d:
                qu = input("Enter quatity to update : ")
                d[update_fruit] = qu
            else:
                print("fruit is not available in data !")
    except:
            print("something is wrong")
# Out:
# fruit is not available in data !
