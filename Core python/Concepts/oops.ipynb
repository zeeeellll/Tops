# %%
class greet:
    def __init__(self):
        print("Hello world")

# %%
obj = greet()
# Out:
# Hello world

# %%
obj.__init__()
# Out:
# Hello world

# %%
class Animal:
    def dog(self    ):
        return "veg/nonveg"

# %%
obj1 = Animal()

# %%
obj1.dog()
# Out:
# 'veg/nonveg'

# %%
class
