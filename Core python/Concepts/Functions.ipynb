# %%
def sum3(n1,n2,n3):
    sum_of_threen = n1+n2+n3
    return sum_of_threen

a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
c = int(input("Enter third number : "))

sum3(a,b,c)

# %%
print("Jay Shree Ram")

# %% [markdown]
# Types of Argument
#
# 1. Positional
# 2. default
# 3. Keyword
# 4. Variable
# 5. Variable Keyword

# %%
def power(num1,num2):
    return num1 ** num2

# %%
power(4,4)
# Out:
# 256

# %% [markdown]
# Variable Scope
#
# 1. Local
# 2. Global

# %%
x = 5 
def v():
    x = 10
    return x

print(x)
v()
# Out:
# 5
# 10

# %%
def sum(a,b):
    add = a+b
    return f"Sum of two number : {add} "

a = eval(input("Enter a number : "))
b = eval(input("Enter a number : "))
sum(a,b)
# Out:
# 'Sum of two number : 6 '

# %% [markdown]
# Types of Functions

# %%
#  Write a function that takes a string as input and returns the string in reverse order.

def r_s(s):
    return s[::-1]

s = input("Enter a string to reverse")
r_s(s)
# Out:
# 'yaJ'

# %%
def odd_even(num):
    if(num %2 == 0):
        return f"{num} is even"
    else:
        return f"{num} is odd"

# %%
def sq(n):
    return n**2

sq(4)
# Out:
# 16

# %%
def g(x):
    def h(x):
        x=x+1
        print(f"in h(x), x = {x}")
    x = x+1
    print(f"in g(x), x = {x}")
    x = h(x)
    return x

x = 3
z = g(x)
print(x)
print(z)
# Out:
# in g(x), x = 4
# in h(x), x = 5
# 3
# None

# %%
f = ['strawbery','pineapple','gwava','kiwi','berries']

[i for i in f if(lambda i :'a'in i)(i)]
# Out:
# ['strawbery', 'pineapple', 'gwava']

# %%
l = [1,2,5,78,44,8]
list(map(lambda x : x%2==0 else ))
# Out:
#   Cell In[5], line 2
#     list(map(lambda x: if(x%2==0 )))
#                        ^
# SyntaxError: invalid syntax

# %%
list(filter(lambda i : i.startswith('s'),f))
# Out:
# ['strawbery']

# %%
import functools as f

l = [1,2,3,4,5,6]
f.reduce(lambda x,y:x+y if x > y else y,l)
# Out:
# 6

# %%
def tryy(a,b):
    print(a,b)
tryy(a = 1,b = 2)

def i(*a):
    print(a)

i(1,2,3,4,5)
# Out:
# 1 2
# (1, 2, 3, 4, 5)
