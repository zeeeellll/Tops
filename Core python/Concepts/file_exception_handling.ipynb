# %%
f = open('sample.txt','w')
f.write("Hello world")
f.close()

# %%
f=open("sample.txt",'a')
f.write("\nHelllo")
f.write("\nWorld")
f.close()

# %%
f=open("sample.txt",'w')
f.truncate()
f.close()

# %%
f=open("sample.txt",'a')
f.write("Jay Shree Ram")
f.close()

# %%
f = open("Sample.txt",'r')
f.read()
# Out:
# 'Hello world\nwelcome to the python programming \nhope you leaning is welldone\nwelcome to the python programming all of you ! '

# %%
f = open("sample.txt",'a')
f.write('Hello how are you ? \n i hope you are well and good')
f.close()

# %%
f = open('sample.txt','r')

print(f.read())
# Out:
# Hello world
# welcome to the python programming
# hope you leaning is welldone
# welcome to the python programming all of you !

# %%
f = open('sample.txt','r')
for i in f:
    print(f.readlines(),end='')
    
f.close()
# Out:
# ['welcome to the python programming \n', 'hope you leaning is welldone\n', 'welcome to the python programming all of you ! ']

# %%
f = open('sample.txt','r')
print(f.read())
f.close()
# Out:
# Hello world
# welcome to the python programming
# hope you leaning is welldone
# welcome to the python programming all of you !

# %%
with open('sample.txt') as f:
    print(f.readline())
    print(f.readline())
# Out:
# Hello world
#
# welcome to the python programming

# %%
with open('sample.txt') as f:
    print(f.readline(),end='')
    print(f.readline(50))
# Out:
# Hello world
# welcome to the python programming

# %%
with open('sample.txt','a') as f:
    f.write("welcome to the python programming all of you ! ")
    # print(f.read())

# %%
with open('sample.txt') as f:
    print(f.read())
# Out:
# Hello world
# welcome to the python programming
# hope you leaning is welldone
# welcome to the python programming all of you ! welcome to the python programming all of you !

# %%
with open('sample.txt','r') as f:
    while True:
        d = f.readline()
        if d == '':
            break
        else:
            print(d,end='')
# Out:
# Hello world
# welcome to the python programming
# hope you leaning is welldone
# welcome to the python programming all of you !

# %%
with open('sample.txt','r') as f:
    while True:
        d = f.readline()
        if d == '':
            break
        else:
            print(d)
# Out:
# Hello world
#
# welcome to the python programming
#
# hope you leaning is welldone
#
# welcome to the python programming all of you !

# %% [markdown]
# ### Exception Handling

# %%
a = (
# Out:
#   Cell In[1], line 1
#     a = (
#          ^
# SyntaxError: incomplete input

# %%
if i = 0;
# Out:
#   Cell In[2], line 1
#     if i = 0;
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
try :
    i == 0
except:
    print("invalid statement")
# Out:
# invalid statement

# %%
i = 0
if i == 1 :
    pass
else:
    print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       3     pass
#       4 else:
# ----> 5     print(a)
#
# NameError: name 'a' is not defined

# %%
try :
    i = 0
    if i == 1 :
        pass
    else:
        print(a)

except :
    print("a is not define")
# Out:
# a is not define

# %%
try :
    i = 0
    if i == 1 :
        pass
    else:
        print(a)

except Exception as e:
    print(e)
# Out:
# name 'a' is not defined

# %%
try :
    with open('ese.txt','r') as f:
        f.read()
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'ese.txt'

# %%
try :
    with open('ese.txt','r') as f:
        f.read()
except Exception as e:
    print("File can't founr")
# Out:
# File can't founr

# %%
try :
    fahrenheit = float(input("Enter temperature in Fahrenheit: "))
    
    if type(fahrenheit) == int:
         raise ValueError("Enter valid value")
    else:
        celsius = (fahrenheit - 32) * 5/9
        print(f"{fahrenheit}.F is equal to {celsius:.2f}°C")

    celsius = float(input("Enter temperature in Celsius: "))
    fahrenheit = (celsius * 9/5) + 32

    print(f"{celsius}.C is equal to {fahrenheit:.2f}°F")

   

except Exception as e:
    print(e)
# Out:
# 8.9.F is equal to -12.83°C
# 8.0.C is equal to 46.40°F

# %%
a = int(input())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 a = int(input())
#
# ValueError: invalid literal for int() with base 10: '5.5'

# %%
try :
    t = float(input("Enterr temprature : "))
    u = input("Enter F for Faherenheit and C for celsius ")

    if u.upper() == 'F':
        con = (t-31)*5/9
        print(con)
    elif u.upper() == 'C':
        con = (9/5* t) + 32
        print(con)
    else:
        raise ValueError("Invalid unit")
except Exception as e:
    print(e)
# Out:
# Invalid unit

# %%
try :
    5/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try :
    t = (1,2,3,4,5)
    t.append(0)
    print(t)
except Exception as e:
    print(e)
# Out:
# 'tuple' object has no attribute 'append'

# %%
try:
    numerator = int(input("Enter numerator: "))
    denominator = int(input("Enter denominator: "))
    
    result = numerator / denominator  
    print("Result:", result)

    numbers = [10, 20, 30]
    print("Accessing index 5:", numbers[5])  

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except IndexError:
    print("Error: Index out of range.")
except ValueError:
    print("Error: Invalid input! Please enter a number.")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Result: 10.0
# Error: Index out of range.

# %%
try:
    file = open("example.txt", "r")  
    content = file.read()
    print(content)

except FileNotFoundError:
    print("Error: File not found.")

finally:
    print("Closing file...")
# Out:
# Error: File not found.
# Closing file...
